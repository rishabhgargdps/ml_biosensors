# %%
#Code added for warnings
import warnings
warnings.filterwarnings('ignore')

from numpy import *
import numpy as np
import pandas as pd
import sklearn as sk
from sklearn.model_selection import train_test_split
from tensorflow.python.framework import ops
from sklearn import preprocessing
from sklearn import svm
import os
from sklearn import manifold
import matplotlib.pyplot as plt

# input data
data_train=pd.read_csv('EIS-data-demo.csv',sep=',')

# Code added for error handling
data_train = data_train.replace([np.inf, -np.inf], np.nan)
data_train = data_train.dropna()

labels=data_train['Type'][:,np.newaxis]
features=data_train.drop('Type', axis=1)#'DOI',


X_train,X_test,Y_train,Y_test=train_test_split(features, labels, test_size=0.2, random_state=0)

####   grid search start
df = pd.DataFrame(data = None, columns = {"score", "gamma", "C"})
best_score = 0
maximum = 0
for gamma in [0.25,5,1,0.4,0.1,0.15,0.2,0.3,0.35,0.45,0.5,2]:
    for C in [0.1,0.5,1,1.5,2,2.5,3,3.5,4,4.5,5,10]:
        clf_rbf = svm.SVC(kernel='rbf',C=C,gamma=gamma,probability=True)
        clf_rbf.fit(X_train,Y_train)
        rbf_test = clf_rbf.score(X_test,Y_test)
        maximum = max(maximum, rbf_test)
        parameters = {'gamma':gamma,'C':C}
        print(rbf_test)
        print("Best parameters:{}".format(parameters))
        df.loc[len(df)] = [rbf_test, gamma, C]
df.to_csv("output.csv", sep = ",")
# Out:
# 0.1935483870967742
# Best parameters:{'gamma': 0.25, 'C': 0.1}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 0.5}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 1}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 1.5}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 2}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 2.5}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 3}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 3.5}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 4}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 4.5}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 5}
# 0.3870967741935484
# Best parameters:{'gamma': 0.25, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 5, 'C': 0.1}
# 0.1935483870967742
# Best parameters:{'gamma': 5, 'C': 0.5}
# 0.2903225806451613
# Best parameters:{'gamma': 5, 'C': 1}
# 0.3548387096774194
# Best parameters:{'gamma': 5, 'C': 1.5}
# 0.3548387096774194
# Best parameters:{'gamma': 5, 'C': 2}
# 0.3548387096774194
# Best parameters:{'gamma': 5, 'C': 2.5}
# 0.3548387096774194
# Best parameters:{'gamma': 5, 'C': 3}
# 0.3548387096774194
# Best parameters:{'gamma': 5, 'C': 3.5}
# 0.3548387096774194
# Best parameters:{'gamma': 5, 'C': 4}
# 0.3548387096774194
# Best parameters:{'gamma': 5, 'C': 4.5}
# 0.3548387096774194
# Best parameters:{'gamma': 5, 'C': 5}
# 0.3548387096774194
# Best parameters:{'gamma': 5, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 1, 'C': 0.1}
# 0.3225806451612903
# Best parameters:{'gamma': 1, 'C': 0.5}
# 0.3225806451612903
# Best parameters:{'gamma': 1, 'C': 1}
# 0.3548387096774194
# Best parameters:{'gamma': 1, 'C': 1.5}
# 0.3548387096774194
# Best parameters:{'gamma': 1, 'C': 2}
# 0.3548387096774194
# Best parameters:{'gamma': 1, 'C': 2.5}
# 0.3548387096774194
# Best parameters:{'gamma': 1, 'C': 3}
# 0.3548387096774194
# Best parameters:{'gamma': 1, 'C': 3.5}
# 0.3548387096774194
# Best parameters:{'gamma': 1, 'C': 4}
# 0.3548387096774194
# Best parameters:{'gamma': 1, 'C': 4.5}
# 0.3870967741935484
# Best parameters:{'gamma': 1, 'C': 5}
# 0.3870967741935484
# Best parameters:{'gamma': 1, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 0.4, 'C': 0.1}
# 0.2903225806451613
# Best parameters:{'gamma': 0.4, 'C': 0.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.4, 'C': 1}
# 0.3548387096774194
# Best parameters:{'gamma': 0.4, 'C': 1.5}
# 0.3870967741935484
# Best parameters:{'gamma': 0.4, 'C': 2}
# 0.3548387096774194
# Best parameters:{'gamma': 0.4, 'C': 2.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.4, 'C': 3}
# 0.3225806451612903
# Best parameters:{'gamma': 0.4, 'C': 3.5}
# 0.3225806451612903
# Best parameters:{'gamma': 0.4, 'C': 4}
# 0.3548387096774194
# Best parameters:{'gamma': 0.4, 'C': 4.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.4, 'C': 5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.4, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 0.1, 'C': 0.1}
# 0.41935483870967744
# Best parameters:{'gamma': 0.1, 'C': 0.5}
# 0.5161290322580645
# Best parameters:{'gamma': 0.1, 'C': 1}
# 0.6129032258064516
# Best parameters:{'gamma': 0.1, 'C': 1.5}
# 0.6129032258064516
# Best parameters:{'gamma': 0.1, 'C': 2}
# 0.5806451612903226
# Best parameters:{'gamma': 0.1, 'C': 2.5}
# 0.5806451612903226
# Best parameters:{'gamma': 0.1, 'C': 3}
# 0.5483870967741935
# Best parameters:{'gamma': 0.1, 'C': 3.5}
# 0.5483870967741935
# Best parameters:{'gamma': 0.1, 'C': 4}
# 0.5483870967741935
# Best parameters:{'gamma': 0.1, 'C': 4.5}
# 0.5483870967741935
# Best parameters:{'gamma': 0.1, 'C': 5}
# 0.5161290322580645
# Best parameters:{'gamma': 0.1, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 0.15, 'C': 0.1}
# 0.3548387096774194
# Best parameters:{'gamma': 0.15, 'C': 0.5}
# 0.4838709677419355
# Best parameters:{'gamma': 0.15, 'C': 1}
# 0.5806451612903226
# Best parameters:{'gamma': 0.15, 'C': 1.5}
# 0.5483870967741935
# Best parameters:{'gamma': 0.15, 'C': 2}
# 0.5483870967741935
# Best parameters:{'gamma': 0.15, 'C': 2.5}
# 0.5483870967741935
# Best parameters:{'gamma': 0.15, 'C': 3}
# 0.5483870967741935
# Best parameters:{'gamma': 0.15, 'C': 3.5}
# 0.5483870967741935
# Best parameters:{'gamma': 0.15, 'C': 4}
# 0.5483870967741935
# Best parameters:{'gamma': 0.15, 'C': 4.5}
# 0.5483870967741935
# Best parameters:{'gamma': 0.15, 'C': 5}
# 0.5483870967741935
# Best parameters:{'gamma': 0.15, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 0.2, 'C': 0.1}
# 0.3548387096774194
# Best parameters:{'gamma': 0.2, 'C': 0.5}
# 0.4838709677419355
# Best parameters:{'gamma': 0.2, 'C': 1}
# 0.5161290322580645
# Best parameters:{'gamma': 0.2, 'C': 1.5}
# 0.5161290322580645
# Best parameters:{'gamma': 0.2, 'C': 2}
# 0.5161290322580645
# Best parameters:{'gamma': 0.2, 'C': 2.5}
# 0.5161290322580645
# Best parameters:{'gamma': 0.2, 'C': 3}
# 0.5161290322580645
# Best parameters:{'gamma': 0.2, 'C': 3.5}
# 0.5161290322580645
# Best parameters:{'gamma': 0.2, 'C': 4}
# 0.5483870967741935
# Best parameters:{'gamma': 0.2, 'C': 4.5}
# 0.5483870967741935
# Best parameters:{'gamma': 0.2, 'C': 5}
# 0.5161290322580645
# Best parameters:{'gamma': 0.2, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 0.3, 'C': 0.1}
# 0.3548387096774194
# Best parameters:{'gamma': 0.3, 'C': 0.5}
# 0.3225806451612903
# Best parameters:{'gamma': 0.3, 'C': 1}
# 0.3548387096774194
# Best parameters:{'gamma': 0.3, 'C': 1.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.3, 'C': 2}
# 0.3870967741935484
# Best parameters:{'gamma': 0.3, 'C': 2.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.3, 'C': 3}
# 0.3548387096774194
# Best parameters:{'gamma': 0.3, 'C': 3.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.3, 'C': 4}
# 0.2903225806451613
# Best parameters:{'gamma': 0.3, 'C': 4.5}
# 0.2903225806451613
# Best parameters:{'gamma': 0.3, 'C': 5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.3, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 0.35, 'C': 0.1}
# 0.2903225806451613
# Best parameters:{'gamma': 0.35, 'C': 0.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.35, 'C': 1}
# 0.3870967741935484
# Best parameters:{'gamma': 0.35, 'C': 1.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.35, 'C': 2}
# 0.3548387096774194
# Best parameters:{'gamma': 0.35, 'C': 2.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.35, 'C': 3}
# 0.3548387096774194
# Best parameters:{'gamma': 0.35, 'C': 3.5}
# 0.3225806451612903
# Best parameters:{'gamma': 0.35, 'C': 4}
# 0.3225806451612903
# Best parameters:{'gamma': 0.35, 'C': 4.5}
# 0.3225806451612903
# Best parameters:{'gamma': 0.35, 'C': 5}
# 0.3870967741935484
# Best parameters:{'gamma': 0.35, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 0.45, 'C': 0.1}
# 0.2903225806451613
# Best parameters:{'gamma': 0.45, 'C': 0.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.45, 'C': 1}
# 0.3870967741935484
# Best parameters:{'gamma': 0.45, 'C': 1.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.45, 'C': 2}
# 0.3548387096774194
# Best parameters:{'gamma': 0.45, 'C': 2.5}
# 0.3225806451612903
# Best parameters:{'gamma': 0.45, 'C': 3}
# 0.3225806451612903
# Best parameters:{'gamma': 0.45, 'C': 3.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.45, 'C': 4}
# 0.3548387096774194
# Best parameters:{'gamma': 0.45, 'C': 4.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.45, 'C': 5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.45, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 0.5, 'C': 0.1}
# 0.3225806451612903
# Best parameters:{'gamma': 0.5, 'C': 0.5}
# 0.3870967741935484
# Best parameters:{'gamma': 0.5, 'C': 1}
# 0.3870967741935484
# Best parameters:{'gamma': 0.5, 'C': 1.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.5, 'C': 2}
# 0.3548387096774194
# Best parameters:{'gamma': 0.5, 'C': 2.5}
# 0.3225806451612903
# Best parameters:{'gamma': 0.5, 'C': 3}
# 0.3548387096774194
# Best parameters:{'gamma': 0.5, 'C': 3.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.5, 'C': 4}
# 0.3548387096774194
# Best parameters:{'gamma': 0.5, 'C': 4.5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.5, 'C': 5}
# 0.3548387096774194
# Best parameters:{'gamma': 0.5, 'C': 10}
# 0.1935483870967742
# Best parameters:{'gamma': 2, 'C': 0.1}
# 0.22580645161290322
# Best parameters:{'gamma': 2, 'C': 0.5}
# 0.3548387096774194
# Best parameters:{'gamma': 2, 'C': 1}
# 0.3225806451612903
# Best parameters:{'gamma': 2, 'C': 1.5}
# 0.3225806451612903
# Best parameters:{'gamma': 2, 'C': 2}
# 0.3548387096774194
# Best parameters:{'gamma': 2, 'C': 2.5}
# 0.3548387096774194
# Best parameters:{'gamma': 2, 'C': 3}
# 0.3548387096774194
# Best parameters:{'gamma': 2, 'C': 3.5}
# 0.3548387096774194
# Best parameters:{'gamma': 2, 'C': 4}
# 0.3548387096774194
# Best parameters:{'gamma': 2, 'C': 4.5}
# 0.3548387096774194
# Best parameters:{'gamma': 2, 'C': 5}
# 0.3548387096774194
# Best parameters:{'gamma': 2, 'C': 10}

# %%
print(maximum)
# Out:
# 0.6129032258064516

# %%
df.to_csv("output.csv", sep = ",")
