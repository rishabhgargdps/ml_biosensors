# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./ML_mat.csv')

# %%
df
# Out:
#      Z1    Z2  Unnamed: 2  ...  Unnamed: 120  Unnamed: 121    KCl
# 0  58.0  58.8        60.0  ...         -73.9         -73.0   10.0
# 1  54.6  55.6        56.7  ...         -75.2         -75.3   25.0
# 2  53.3  54.2        55.4  ...         -75.9         -75.8   50.0
# 3  52.3  53.3        54.4  ...         -74.6         -74.2  100.0
#
# [4 rows x 123 columns]

# %%
X = df.iloc[:, df.columns != "KCl"].values
y = df["KCl"].values

# %%
#Completely using the dataset for training
import xgboost
from xgboost import XGBRegressor
model = XGBRegressor()
model.fit(X, y)
print(model.predict([X[0]]), model.predict([X[1]]), model.predict([X[2]]), model.predict([X[3]]))
# Out:
# [13:56:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [9.990597] [24.960293] [49.851154] [99.39097]

# %%
#75% training 25% test data
model = XGBRegressor()
X_train = df.iloc[0:3, df.columns != "KCl"].values
y_train = df.iloc[0:3, df.columns == "KCl"].values.ravel()
model.fit(X_train, y_train)
print(model.predict([X[0]]), model.predict([X[1]]), model.predict([X[2]]), model.predict([X[3]]))
# Out:
# [13:56:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [9.980018] [24.920954] [49.69825] [49.69825]

# %%
#75% training 25% test data
model = XGBRegressor(n_estimators=500, max_depth=70)
X_train = df.iloc[0:3, df.columns != "KCl"].values
y_train = df.iloc[0:3, df.columns == "KCl"].values.ravel()
model.fit(X_train, y_train)
print(model.predict([X[0]]), model.predict([X[1]]), model.predict([X[2]]), model.predict([X[3]]))
# Out:
# [13:56:48] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10.000914] [25.000158] [49.99891] [49.99891]

# %%
#50% training 50% test data
model = XGBRegressor(n_estimators=500, max_depth=10)
X_train = df.iloc[0:2, df.columns != "KCl"].values
y_train = df.iloc[0:2, df.columns == "KCl"].values.ravel()
model.fit(X_train, y_train)
print(model.predict([X[0]]), model.predict([X[1]]), model.predict([X[2]]), model.predict([X[3]]))
# Out:
# [13:56:49] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [10.000946] [24.999039] [24.999039] [24.999039]

# %%
#Preprocessing:- Min Max scaling
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = df.iloc[0:3, df.columns != "KCl"].values
y_train = df.iloc[0:3, df.columns == "KCl"].values.ravel()
X_train_scaled = scaler.fit_transform(X_train)
X_train = pd.DataFrame(X_train_scaled)
model.fit(X_train, y_train)
X_test = df.iloc[3, df.columns != "KCl"].values
X_test_scaled = scaler.transform([X_test])
X_test = pd.DataFrame(X_test_scaled)
model.predict(X_test)
# Out:
# [13:56:50] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# array([49.99891], dtype=float32)
